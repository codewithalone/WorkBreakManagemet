# %%
import pandas as pd

item={"Chocolate":15,"Chips":7,"Milk":"NO"}
itempd=pd.Series(item)
print(itempd)
print(type(itempd))
# Out:
# Chocolate    15
# Chips         7
# Milk         NO
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
# printing while iterating
for key in item:
    print(key,item[key])
# Out:
# Chocolate 15
# Chips 7
# Milk NO

# %%
itempd.shape
itempd.index
# itempd.values
# Out:
# Index(['Chocolate', 'Chips', 'Milk'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 item[0]
#
# KeyError: 0

# %%
itempd.loc[['Milk','Chips']]
# Out:
# Milk     NO
# Chips     7
# dtype: object

# %%
itempd.iloc[[0,2]]
# Out:
# Chocolate    15
# Milk         NO
# dtype: object

# %%
i=itempd.drop('Chocolate')

# %%
i
# Out:
# Chips     7
# Milk     NO
# dtype: object

# %%
#Arithematic optr
sweets=pd.Series({"Candies":13,"Donuts":7,"Ladoos":25})
sweets
# Out:
# Candies    13
# Donuts      7
# Ladoos     25
# dtype: int64

# %%
sweets+2
# Out:
# Candies    15
# Donuts      9
# Ladoos     27
# dtype: int64

# %%
sweets-2
# Out:
# Candies    11
# Donuts      5
# Ladoos     23
# dtype: int64

# %%
sweets/2
# Out:
# Candies     6.5
# Donuts      3.5
# Ladoos     12.5
# dtype: float64

# %%
sweets["Candies"]-2
# Out:
# 11

# %%
First_name=["Harsh","Piyush","Shivam","Tanmay","Soham"]
last_name=["Mishra","Jha","Jha","Murkute","Kotkar"]
gender=["male","male","male","female","female"]
marks=[35,34,37,32,28]

data=pd.DataFrame({"First_name":["Harsh","Piyush","Shivam","Tanmay","Soham"],
"last_name":["Mishra","Jha","Jha","Murkute","Kotkar"],
"gender":["male","male","male","female","female"],
"marks":[35,34,37,32,28],
"rollno":[57,9,34,60,51]})
print(data)
# Out:
#   First_name last_name  gender  marks  rollno
# 0      Harsh    Mishra    male     35      57
# 1     Piyush       Jha    male     34       9
# 2     Shivam       Jha    male     37      34
# 3     Tanmay   Murkute  female     32      60
# 4      Soham    Kotkar  female     28      51

# %%
data["last_name"]
# Out:
# 0     Mishra
# 1        Jha
# 2        Jha
# 3    Murkute
# 4     Kotkar
# Name: last_name, dtype: object

# %%
data["marks"][4]
# Out:
# 28

# %%
data[0:3]
# Out:
#   First_name last_name gender  marks  Rollno
# 0      Harsh    Mishra   male     35      57
# 1     Piyush       Jha   male     34       9
# 2     Shivam       Jha   male     37      34

# %%
data[1:]
# Out:
#   First_name last_name  gender  marks  Rollno
# 1     Piyush       Jha    male     34       9
# 2     Shivam       Jha    male     37      34
# 3     Tanmay   Murkute  female     32      60
# 4      Soham    Kotkar  female     28      51

# %%
data=data.set_index('rollno')
data
# Out:
#        First_name last_name  gender  marks
# rollno
# 57          Harsh    Mishra    male     35
# 9          Piyush       Jha    male     34
# 34         Shivam       Jha    male     37
# 60         Tanmay   Murkute  female     32
# 51          Soham    Kotkar  female     28

# %%
data["First_name"].loc[[57,9]]
# Out:
# rollno
# 57     Harsh
# 9     Piyush
# Name: First_name, dtype: object

# %%
data["First_name"].iloc[[0,3]]
# Out:
# rollno
# 57     Harsh
# 60    Tanmay
# Name: First_name, dtype: object

# %%
data.index
# Out:
# Int64Index([57, 9, 34, 60, 51], dtype='int64', name='rollno')

# %%
data.values
# Out:
# array([['Harsh', 'Mishra', 'male', 35],
#        ['Piyush', 'Jha', 'male', 34],
#        ['Shivam', 'Jha', 'male', 37],
#        ['Tanmay', 'Murkute', 'female', 32],
#        ['Soham', 'Kotkar', 'female', 28]], dtype=object)

# %%
data["First_name"][60]
# Out:
# 'Tanmay'

# %%
# for the adding the new col we had use tis method
data["Age"]=[19,20,10,27,32]
data
# Out:
#        First_name last_name  gender  marks  Age
# rollno
# 57          Harsh    Mishra    male     35   19
# 9          Piyush       Jha    male     34   20
# 34         Shivam       Jha    male     37   10
# 60         Tanmay   Murkute  female     32   27
# 51          Soham    Kotkar  female     28   32

# %%
# for change in the table as we want marks in scale of 100
data["marks_in_100"]=data["marks"]*2
data
# Out:
#        First_name last_name  gender  marks  Age  marks_in_100
# rollno
# 57          Harsh    Mishra    male     35   19            70
# 9          Piyush       Jha    male     34   20            68
# 34         Shivam       Jha    male     37   10            74
# 60         Tanmay   Murkute  female     32   27            64
# 51          Soham    Kotkar  female     28   32            56

# %%
new_roll=[{"First_name":"Dhvani","last_name":"Khatri","gender":"female","marks":24,"Age":19}]
new_data=pd.DataFrame(new_roll,index=[45])
new_data
# Out:
#    First_name last_name  gender  marks  Age
# 45     Dhvani    Khatri  female     24   19

# %%
data=data.append(new_data)
data
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_8544\1454323961.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(new_data)
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0
# 45     Dhvani    Khatri  female     24   19           NaN

# %%
pd.concat([data,new_data])
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0
# 45     Dhvani    Khatri  female     24   19           NaN
# 45     Dhvani    Khatri  female     24   19           NaN

# %%
data.drop(45)
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0

# %%
data.rename(columns={"First_name":"first_name"})
# Out:
#    first_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0
# 45     Dhvani    Khatri  female     24   19           NaN

# %%
data.rename(index={9:8})
# Out:
#    First_name last_name  gender  marks   Age  marks_in_100
# 57      Harsh    Mishra    male     35  19.0          70.0
# 8      Piyush       Jha    male     34  20.0          68.0
# 34     Shivam       Jha    male     37  10.0          74.0
# 60     Tanmay   Murkute  female     32  27.0          64.0
# 51      Soham    Kotkar  female     28  32.0          56.0
# 45     Dhvani    Khatri  female     24   NaN           NaN
# 45     Dhvani    Khatri  female     24  19.0           NaN
# 45     Dhvani    Khatri  female     24  19.0           NaN

# %%
data.isnull()
# Out:
#     First_name  last_name  gender  marks    Age  marks_in_100
# 57       False      False   False  False  False         False
# 9        False      False   False  False  False         False
# 34       False      False   False  False  False         False
# 60       False      False   False  False  False         False
# 51       False      False   False  False  False         False
# 45       False      False   False  False  False          True

# %%
data.isnull().sum()
# Out:
# First_name      0
# last_name       0
# gender          0
# marks           0
# Age             0
# marks_in_100    1
# dtype: int64

# %%
data.count()
# Out:
# First_name      6
# last_name       6
# gender          6
# marks           6
# Age             6
# marks_in_100    5
# dtype: int64

# %%
# this is used delete all null value
data.dropna(axis=0)
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0

# %%
# this is used to fill value in null place
data.fillna(0.88)
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19         70.00
# 9      Piyush       Jha    male     34   20         68.00
# 34     Shivam       Jha    male     37   10         74.00
# 60     Tanmay   Murkute  female     32   27         64.00
# 51      Soham    Kotkar  female     28   32         56.00
# 45     Dhvani    Khatri  female     24   19          0.88

# %%
# we replace NaN values with the previous value in the column
# this called forward fill
data.fillna(method='ffill',axis=0)
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0
# 45     Dhvani    Khatri  female     24   19          56.0

# %%
# we replace NaN values with the next value in the column
# this called as backfill
data.fillna(method='backfill',axis=0)
# Out:
#    First_name last_name  gender  marks  Age  marks_in_100
# 57      Harsh    Mishra    male     35   19          70.0
# 9      Piyush       Jha    male     34   20          68.0
# 34     Shivam       Jha    male     37   10          74.0
# 60     Tanmay   Murkute  female     32   27          64.0
# 51      Soham    Kotkar  female     28   32          56.0
# 45     Dhvani    Khatri  female     24   19           NaN

# %%
import pandas as pd
stock=pd.read_csv("C:/Users/harsh/Downloads/stocks.csv")
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
stock["Open"]* stock["Volume"]+stock["Close"]
# Out:
# 0       2.235187e+09
# 1       1.154400e+09
# 2       1.011942e+09
# 3       8.489021e+08
# 4       4.826890e+08
#             ...
# 3308    8.735730e+08
# 3309    9.490330e+08
# 3310    1.648801e+09
# 3311    1.246558e+09
# 3312    1.148439e+09
# Length: 3313, dtype: float64

# %%
print(type(stock))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(stock.shape)
# Out:
# (3313, 7)

# %%
stock.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400
# 5  2004-08-26  52.135906  53.626213  51.991844  53.606342  53.606342   7148200
# 6  2004-08-27  53.700729  53.959049  52.503513  52.732029  52.732029   6258300
# 7  2004-08-30  52.299839  52.404160  50.675404  50.675404  50.675404   5235700
# 8  2004-08-31  50.819469  51.519913  50.749920  50.854240  50.854240   4954800
# 9  2004-09-01  51.018177  51.152302  49.512966  49.801090  49.801090   9206800

# %%
stock.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data=pd.read_csv("C:/Users/harsh/Downloads/fake_company.csv")
data
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991    Alice         HR   26   52000
# 4  1991      Bob         RD   31   50000
# 5  1991  Charlie      Admin   46   60000
# 6  1992    Alice      Admin   27   60000
# 7  1992      Bob         RD   32   52000
# 8  1992  Charlie      Admin   28   62000

# %%
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
titanic=pd.read_csv("C:/Users/harsh/Downloads/train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
import numpy as np

arr=np.array([4,5,6,1,2,4,6,7,8,1,9,1,2,43,4])
arr[(arr%2==0) & (arr>4)]
# Out:
# array([6, 6, 8])

# %%
#filtering

titanic[titanic["Survived"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic["Survived"]==1]["Sex"].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
titanic[(titanic["Survived"]==1) & (titanic["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titanic.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic["Name"].isnull().sum()
# Out:
# 0

# %%
lname=[]
for i in range(0, len(titanic["Name"])):
    lname.append(titanic["Name"][i].split(",")[0])

titanic["last_Name"]=lname
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Most preferred one
def get_last_name(name):
    res=name.split(",")[0]
    return res

titanic["Name"].apply(get_last_name)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
# Or u can use lambda function

titanic["Name"].apply(lambda name:name.split(",")[0])
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
titanic["gender_numeric"]=(titanic["Sex"]=="male").astype(int)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Embarked"].isnull().sum()
# Out:
# 2

# %%
titanic["Embarked"].map({"S":0,"C":1,"Q":2})
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 886    0.0
# 887    0.0
# 888    0.0
# 889    1.0
# 890    2.0
# Name: Embarked, Length: 891, dtype: float64

# %%
titanic[titanic["Embarked"].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked last_Name  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN     Icard
# 829  female  62.0      0      0  113572  80.0   B28      NaN     Stone
#
#      gender_numeric
# 61                0
# 829               0

# %%
print(titanic[titanic["Sex"]=="male"]["Age"].mean())
print(titanic[titanic["Sex"]=="male"]["Age"].mean())
# Out:
# 30.72664459161148
# 30.72664459161148

# %%
titanic.groupby(["Survived"]).mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12344\1449984019.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["Survived"]).mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
#           gender_numeric
# Survived
# 0               0.852459
# 1               0.318713

# %%
titanic.groupby(["Sex"])["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby(["Embarked"]).mean()[["Age","Fare"]]
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12344\2369543418.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["Embarked"]).mean()[["Age","Fare"]]
#                 Age       Fare
# Embarked
# C         30.814769  59.954144
# Q         28.089286  13.276030
# S         29.445397  27.079812

# %%
print(titanic[(titanic["Sex"]=="male") & titanic["Survived"]==1]["Age"].mean())
print(titanic[(titanic["Sex"]=="male") & titanic["Survived"]==0]["Age"].mean())
# Out:
# 27.276021505376345
# 30.061996779388085

# %%
titanic.groupby(["Sex","Survived"]).mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12344\1363577129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["Sex","Survived"]).mean()
#                  PassengerId    Pclass        Age     SibSp     Parch  \
# Sex    Survived
# female 0          434.851852  2.851852  25.046875  1.209877  1.037037
#        1          429.699571  1.918455  28.847716  0.515021  0.515021
# male   0          449.121795  2.476496  31.618056  0.440171  0.207265
#        1          475.724771  2.018349  27.276022  0.385321  0.357798
#
#                       Fare  gender_numeric
# Sex    Survived
# female 0         23.024385             0.0
#        1         51.938573             0.0
# male   0         21.960993             1.0
#        1         40.821484             1.0

# %%
titanic.groupby(["Sex","Survived","Pclass"]).mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12344\3007642697.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["Sex","Survived","Pclass"]).mean()
#                         PassengerId        Age     SibSp     Parch  \
# Sex    Survived Pclass
# female 0        1        325.000000  25.666667  0.666667  1.333333
#                 2        423.500000  36.000000  0.500000  0.166667
#                 3        440.375000  23.818182  1.291667  1.097222
#        1        1        473.967033  34.939024  0.549451  0.428571
#                 2        444.785714  28.080882  0.485714  0.642857
#                 3        359.083333  19.329787  0.500000  0.500000
# male   0        1        413.623377  44.581967  0.272727  0.259740
# ...
