# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

store_df=pd.read_csv("C:/Users/harsh/Downloads/Walmart.csv")
store_df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
sb.histplot(x=store_df["Weekly_Sales"]<1000000)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot: xlabel='Weekly_Sales', ylabel='Count'>

# %%
# count the number of negative values in "weekly sales"
(store_df["Weekly_Sales"]<0).value_counts()
# Out:
# False    6435
# Name: Weekly_Sales, dtype: int64

# %%
store_df.isna().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# drop all rows where weekly sales is negative

store_df.drop(6434)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6429     45  21-09-2012     723086.20             0        65.32       4.038
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
#
#              CPI  Unemployment
# ...

# %%
store_df.drop([6434,6433])
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6428     45  14-09-2012     702238.27             0        67.87       3.948
# 6429     45  21-09-2012     723086.20             0        65.32       4.038
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
#
#              CPI  Unemployment
# ...

# %%
negsale=store_df[store_df["Weekly_Sales"]<800000].index
store_df.drop(negsale)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6412     45  25-05-2012     817741.17             0        67.21       3.798
# 6413     45  01-06-2012     837144.63             0        74.48       3.742
# 6415     45  15-06-2012     821498.18             0        71.93       3.620
# 6416     45  22-06-2012     822569.16             0        74.22       3.564
# 6418     45  06-07-2012     843361.10             0        82.99       3.475
#
#              CPI  Unemployment
# ...

# %%
store_df.drop(["Unemployment"],axis=1)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI
# 0     211.096358
# ...

# %%
# drop all the data from the above dataframe where holiday is 1

store_df.drop((store_df[store_df["Holiday_Flag"]==1]).index)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# 5         1  12-03-2010    1439541.59             0        57.79       2.667
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
print(pd.to_datetime(store_df["Date"][0]).year)
print(pd.to_datetime(store_df["Date"][0]).day)
print(pd.to_datetime(store_df["Date"][0]).month)
# Out:
# 2010
# 2
# 5

# %%
# to want all day of date 
# same as day we can do this for week month and year
pd.to_datetime(store_df["Date"]).dt.day
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_9828\3663634443.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.to_datetime(store_df["Date"]).dt.day
# 0        2
# 1        2
# 2       19
# 3       26
# 4        3
#         ..
# 6430    28
# 6431    10
# 6432    10
# 6433    19
# 6434    26
# Name: Date, Length: 6435, dtype: int64

# %%
store_df["Date"]=pd.to_datetime(store_df["Date"])
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_9828\1587789854.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   store_df["Date"]=pd.to_datetime(store_df["Date"])

# %%
store_df["Day"]=store_df["Date"].dt.day
store_df
# same as this we can do for month year etc
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Day
# ...

# %%
train_df=pd.read_csv("C:/Users/harsh/Downloads/stocks.csv")
train_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
store_df[(store_df["Store"]==1) &(train_df["Temperature"]>=45)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\harsh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature'
#
# ...

# %%
# we can the data using merge function
train_df[(train_df["Volume"]>=1000000) & (train_df["Open"]>=950)]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3213  2017-05-24  952.979980  955.090027  949.500000  954.960022  954.960022
# 3214  2017-05-25  957.330017  972.629028  955.469971  969.539978  969.539978
# 3215  2017-05-26  969.700012  974.979980  965.030029  971.469971  971.469971
# 3216  2017-05-30  970.309998  976.200012  969.489990  975.880005  975.880005
# 3217  2017-05-31  975.020020  979.270020  960.179993  964.859985  964.859985
# 3218  2017-06-01  968.950012  971.500000  960.010010  966.950012  966.950012
# 3219  2017-06-02  969.460022  975.880005  966.000000  975.599976  975.599976
# 3220  2017-06-05  976.549988  986.909973  975.099976  983.679993  983.679993
# 3221  2017-06-06  983.159973  988.250000  975.140015  976.570007  976.570007
# 3222  2017-06-07  980.000000  983.979980  975.940002  980.940002  980.940002
# 3223  2017-06-08  982.349976  984.570007  977.200012  983.409973  983.409973
# ...

# %%
train_df.merge(store_df, how="inner",on=["Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 train_df.merge(store_df, how="inner",on=["Date"])
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
# ...

# %%
# types of joins in sql

# inner join ,outer(full) join,left join,right join

# %%
store_df[(store_df["Store"]==1)]
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1 2010-05-02    1643690.90             0        42.31       2.572
# 1        1 2010-12-02    1641957.44             1        38.51       2.548
# 2        1 2010-02-19    1611968.17             0        39.93       2.514
# 3        1 2010-02-26    1409727.59             0        46.63       2.561
# 4        1 2010-05-03    1554806.68             0        46.50       2.625
# ..     ...        ...           ...           ...          ...         ...
# 138      1 2012-09-28    1437059.26             0        76.08       3.666
# 139      1 2012-05-10    1670785.97             0        68.55       3.617
# 140      1 2012-12-10    1573072.81             0        62.99       3.601
# 141      1 2012-10-19    1508068.77             0        67.97       3.594
# 142      1 2012-10-26    1493659.74             0        69.16       3.506
#
#             CPI  Unemployment  Day
# ...

# %%
store_df.merge(train_df, how="inner",on=["Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 store_df.merge(train_df, how="inner",on=["Date"])
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
# ...

# %%
# We use this for sorting 
store_df.sort_values("Date")
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 606       5 2010-01-10     283178.12             0        71.10       2.603
# 2036     15 2010-01-10     566945.95             0        59.69       2.840
# 5897     42 2010-01-10     481523.93             0        86.01       3.001
# 4610     33 2010-01-10     224294.39             0        91.45       3.001
# 5039     36 2010-01-10     422169.47             0        74.66       2.567
# ...     ...        ...           ...           ...          ...         ...
# 5860     41 2012-12-10    1409544.97             0        39.38       3.760
# 2285     16 2012-12-10     491817.19             0        43.26       3.760
# 1427     10 2012-12-10    1713889.11             0        76.03       4.468
# 3572     25 2012-12-10     697317.41             0        43.74       4.000
# 283       2 2012-12-10    1900745.13             0        60.97       3.601
#
#              CPI  Unemployment  Day
# ...

# %%
# we can as many as column at one time

store_df.sort_values(["Store","Date"])
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 34        1 2010-01-10    1453329.50             0        71.89       2.603
# 8         1 2010-02-04    1594968.28             0        62.27       2.719
# 21        1 2010-02-07    1492418.14             0        80.91       2.669
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# ...     ...        ...           ...           ...          ...         ...
# 6423     45 2012-10-08     733037.32             0        78.65       3.722
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
# 6410     45 2012-11-05     770487.37             0        61.24       3.889
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
#
#              CPI  Unemployment  Day
# ...

# %%
# Scatter plot

plt.figure(figsize=[15,8])
sb.scatterplot(x=store_df["Store"], y=store_df["CPI"],color="red")
# Out:
# <AxesSubplot: xlabel='Store', ylabel='CPI'>

# %%
df=store_df[store_df["Store"]==4]
sb.histplot(df["CPI"])
# Out:
# <AxesSubplot: xlabel='CPI', ylabel='Count'>

# %%
plt.figure(figsize=[30,15])

for i in range(0,45):
    plt.subplot(5,9,i+1)
    df=store_df[store_df["Store"]==i]
    sb.histplot(x=df["Weekly_Sales"])

# %%
plt.figure(figsize=[20,8])
sb.barplot(x=store_df["Store"],y=store_df["Weekly_Sales"])
# Out:
# <AxesSubplot: xlabel='Store', ylabel='Weekly_Sales'>

# %%
# we can use estimator by default estimator is mean
plt.figure(figsize=[20,10])

sb.barplot(x=store_df["Store"],y=store_df["Weekly_Sales"],estimator=sum)
# Out:
# <AxesSubplot: xlabel='Store', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize=[12,6])
ax=sb.barplot(x=store_df["Store"],y=store_df["Weekly_Sales"])
ax.set_xticklabels(labels=["Store"+ str(i) for i in range(1,46)])
plt.xticks(rotation=90)
plt.plot()
# Out:
# []

# %%
store_df["Date"]=pd.to_datetime(store_df["Date"])

# %%
store_df["day"]=store_df["Date"].dt.day
store_df["week"]=store_df["Date"].dt.week
store_df["month"]=store_df["Date"].dt.month
store_df["weekday"]=store_df["Date"].dt.weekday

store_df
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_9828\866904676.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   store_df["week"]=store_df["Date"].dt.week
#       Store                          Date  Weekly_Sales  Holiday_Flag  \
# 0         1 1970-01-01 00:00:00.000000001    1643690.90             0
# 1         1 1970-01-01 00:00:00.000000001    1641957.44             1
# 2         1 1970-01-01 00:00:00.000000001    1611968.17             0
# 3         1 1970-01-01 00:00:00.000000001    1409727.59             0
# 4         1 1970-01-01 00:00:00.000000001    1554806.68             0
# ...     ...                           ...           ...           ...
# 6430     45 1970-01-01 00:00:00.000000001     713173.95             0
# 6431     45 1970-01-01 00:00:00.000000001     733455.07             0
# 6432     45 1970-01-01 00:00:00.000000001     734464.36             0
# ...
